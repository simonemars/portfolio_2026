# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path 
data_path = Path.home() / "Documents" / "projects" / "tennis prediction" / "TML-Database-master" / "2005.csv"
ofive_df = pd.read_csv(data_path)
ofive_df.head(200)
# Out:
#     tourney_id     tourney_name surface  draw_size tourney_level  \
# 0    2005-7308         Adelaide    Hard         32             A
# 1    2005-7308         Adelaide    Hard         32             A
# 2    2005-7308         Adelaide    Hard         32             A
# 3    2005-7308         Adelaide    Hard         32             A
# 4    2005-7308         Adelaide    Hard         32             A
# ..         ...              ...     ...        ...           ...
# 195   2005-580  Australian Open    Hard        128             G
# 196   2005-580  Australian Open    Hard        128             G
# 197   2005-580  Australian Open    Hard        128             G
# 198   2005-580  Australian Open    Hard        128             G
# 199   2005-580  Australian Open    Hard        128             G
#
#      tourney_date  match_num winner_id  winner_seed winner_entry  ...  \
# 0        20050103        1.0      H432          1.0          NaN  ...
# ...
